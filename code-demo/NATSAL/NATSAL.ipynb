# %%
import pandas as pd

# %%
# We also need pyReadStat
# !pip install pyreadstat

# %%
import pyreadstat
df, meta = pyreadstat.read_sav('natsal_3_teaching_open.sav', apply_value_formats=True,formats_as_category=True)

# %%
df.head()
# Out:
#     agrp    rsex ethnicgrpr                     sexidr  \
# 0  25-34    Male      White      Heterosexual/straight
# 1  35-44  Female      White      Heterosexual/straight
# 2  16-24  Female      White      Heterosexual/straight
# 3  45-54  Female  Not white  Not heterosexual/straight
# 4  25-34    Male  Not white  Not heterosexual/straight
#
#                                     rnssecgp_6 adj_imd_quintile  \
# 0  Lower supervisory and technical occupations                3
# 1         Semi-routine and routine occupations                3
# 2               Student in full-time education                4
# 3         Semi-routine and routine occupations  [most deprived]
# 4              Managerial and prof occupations  [most deprived]
#
#            rwcasual            snnolov                     snpres       snold  \
# 0      Always wrong           Disagree                      Agree       Agree
# 1  Not wrong at all              Agree  Neither agree or disagree    Disagree
# ...

# %%
df['agrp'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df['rsex'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df['sexidr'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df['rnssecgp_6'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df['adj_imd_quintile'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df['rwcasual'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df['snnolov'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df['snpres'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df['snold'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df['snmedia'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df.to_csv('natsal_3_teaching_open.csv', index=False)
